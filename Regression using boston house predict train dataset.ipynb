# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Boston House Price Dataset (train.csv)

# %%
df=pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
#apply EDA

# %%
#To check null values
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df.isnull())
plt.show()

# %%
#display No of rows and columns
df.shape
# Out:
# (1460, 81)

# %%
#Display No of rows
df.shape[0]
# Out:
# 1460

# %%
#Display no of columns
df.shape[1]
# Out:
# 81

# %%
#Percentage find of null value of all columns
#formula : sum of null value / no of rows
null_var=df.isnull().sum()/df.shape[0]*100

# %%
null_var
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
#Search those column whose null value > 20%
drop_column=null_var[null_var>20].keys()

# %%
drop_column
# Out:
# Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
drop_column=null_var[null_var>17].keys()

# %%
drop_column
# Out:
# Index(['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
df1=df.drop(columns=drop_column)

# %%
df1.shape
# Out:
# (1460, 75)

# %%
#find percentage after delete
null_var1=df1.isnull().sum()/df1.shape[0]*100

# %%
null_var1
# Out:
# Id               0.0
# MSSubClass       0.0
# MSZoning         0.0
# LotArea          0.0
# Street           0.0
#                 ...
# MoSold           0.0
# YrSold           0.0
# SaleType         0.0
# SaleCondition    0.0
# SalePrice        0.0
# Length: 75, dtype: float64

# %%
#check heatmap for null values
plt.figure(figsize=(25,25))
sns.heatmap(df1.isnull())
plt.show()

# %%
df1.dropna(inplace=True)  #by default row dropna() means to delete null rows

# %%
#check heatmap for null values
plt.figure(figsize=(25,25))
sns.heatmap(df1.isnull())
plt.show()

# %%
df1.isnull().sum().sum()   # no null values in dataset 0 means
# Out:
# 0

# %%
df1.shape
# Out:
# (1338, 75)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1338 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1338 non-null   int64
#  1   MSSubClass     1338 non-null   int64
#  2   MSZoning       1338 non-null   object
#  3   LotArea        1338 non-null   int64
#  4   Street         1338 non-null   object
#  5   LotShape       1338 non-null   object
#  6   LandContour    1338 non-null   object
#  7   Utilities      1338 non-null   object
#  8   LotConfig      1338 non-null   object
#  9   LandSlope      1338 non-null   object
#  10  Neighborhood   1338 non-null   object
#  11  Condition1     1338 non-null   object
#  12  Condition2     1338 non-null   object
#  13  BldgType       1338 non-null   object
#  14  HouseStyle     1338 non-null   object
#  15  OverallQual    1338 non-null   int64
#  16  OverallCond    1338 non-null   int64
# ...

# %%
#numeric column : distplot()
#if verify (drop null rows/cols) : right decision
sns.distplot(df["MSSubClass"])  #freq plot
plt.show()

# %%
sns.distplot(df1["MSSubClass"])  #freq plot
plt.show()

# %%
#Overlapped df and df1 with MSSubClass col
sns.distplot(df["MSSubClass"])  #freq plot
sns.distplot(df1["MSSubClass"])
plt.show()

# %%
#object type col MSZoning
df['MSZoning'].value_counts()/df.shape[0]*100
# Out:
# RL         78.835616
# RM         14.931507
# FV          4.452055
# RH          1.095890
# C (all)     0.684932
# Name: MSZoning, dtype: float64

# %%
df1['MSZoning'].value_counts()/df1.shape[0]*100
# Out:
# RL         79.671151
# RM         14.275037
# FV          4.633782
# RH          0.822123
# C (all)     0.597907
# Name: MSZoning, dtype: float64

# %%
df["MSZoning"].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
df["PavedDrive"].unique()
# Out:
# array(['Y', 'N', 'P'], dtype=object)

# %%
df1.drop("Id",axis=1,inplace=True)

# %%
df1.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# ...

# %%
#To check imporatant features(input column) to predict the target variable(sales Price)
# then use correlation means corr()  (-1 to +1)

# %%
df1.corr()
# Out:
#                MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  \
# MSSubClass       1.000000 -0.134158     0.051690    -0.098153   0.056456
# LotArea         -0.134158  1.000000     0.090451     0.001415  -0.005022
# OverallQual      0.051690  0.090451     1.000000    -0.163080   0.570668
# OverallCond     -0.098153  0.001415    -0.163080     1.000000  -0.417330
# YearBuilt        0.056456 -0.005022     0.570668    -0.417330   1.000000
# YearRemodAdd     0.038513  0.001681     0.549460     0.035076   0.617156
# MasVnrArea       0.031333  0.096727     0.401175    -0.141080   0.299410
# BsmtFinSF1      -0.069053  0.210148     0.197441    -0.060068   0.224264
# BsmtFinSF2      -0.079329  0.110493    -0.086014     0.035698  -0.070403
# BsmtUnfSF       -0.141025 -0.014589     0.292940    -0.161038   0.147762
# TotalBsmtSF     -0.263613  0.267188     0.505897    -0.228020   0.385146
# 1stFlrSF        -0.258787  0.288502     0.481978    -0.144066   0.263585
# ...

# %%
#check heatmap for correlation
plt.figure(figsize=(100,100))
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.scatterplot(data=df1,x="MSSubClass",y="SalePrice")
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.scatterplot(data=df1,x="LotArea",y="SalePrice")
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.scatterplot(data=df1,x="OverallQual",y="SalePrice")
plt.show()
